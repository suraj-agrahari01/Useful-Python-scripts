# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# Load the original image
original_image = Image.open(r"C:\Users\suraj\Desktop\new dataset\cropped\non_smile\1\0001_cropped.jpg")  # Replace with your image path

# Desired dimensions for the padded image
new_width = 224  # Choose the desired new width
new_height = 244  # Choose the desired new height

# Create a new blank image with black background
padded_image = Image.new("RGB", (new_width, new_height), (232, 190, 172))

# Calculate the position to paste the original image
paste_x = (new_width - original_image.width) // 2
paste_y = (new_height - original_image.height) // 2

# Paste the original image onto the padded image
padded_image.paste(original_image, (paste_x, paste_y))

# Save the padded image
padded_image.save(r"C:\Users\suraj\Desktop\new dataset\0001padding.jpg")  # Replace with your desired output path

# %%
from PIL import Image
import os

# Input and output folder paths
input_folder = r"C:\Users\suraj\Desktop\new dataset\new_cropped\smile\16"  # Folder containing input images
output_folder = r"C:\Users\suraj\Desktop\new dataset\padding\smile\16"  # Folder to save padded images

# Desired dimensions for the padded images
new_width = 224  # Choose the desired new width
new_height = 224  # Choose the desired new height

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    

lst = os.listdir(input_folder) # input directory path
file_number = len(lst)

print('file number : ',file_number)

# Iterate through images, detect lips, crop, and display
max_images = file_number  # Limit the number of images processed
image_count = 0

# Process each image in the input folder
for filename in os.listdir(input_folder):
    if image_count >= max_images:
        break

    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):  # Adjust the file extension if needed
        image_count += 1
        # Load the original image
        original_image = Image.open(os.path.join(input_folder, filename))

        # Create a new blank image with black background
        padded_image = Image.new("RGB", (new_width, new_height), (255,215,174))

        # Calculate the position to paste the original image
        paste_x = (new_width - original_image.width) // 2
        paste_y = (new_height - original_image.height) // 2

        # Paste the original image onto the padded image
        padded_image.paste(original_image, (paste_x, paste_y))

        padded_filename = os.path.splitext(filename)[0] + "_padded.jpg"
        output_path = os.path.join(output_folder, padded_filename)  # Use padded_filename here
        padded_image.save(output_path)

        
        print('Converted : ', image_count)

print("Padding and saving complete.")
# Out:
# file number :  0
# Padding and saving complete.

# %%
from PIL import Image
import os

def pad_images_in_folder(input_folder, output_folder, new_width, new_height, max_images=None):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    lst = os.listdir(input_folder)  # Input directory path
    file_number = len(lst)
    print('file number : ', file_number)

    # Iterate through images, pad, and save
    image_count = 0

    for filename in os.listdir(input_folder):
        if max_images is not None and image_count >= max_images:
            break

        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):  # Adjust the file extension if needed
            image_count += 1
            # Load the original image
            original_image = Image.open(os.path.join(input_folder, filename))

            # Create a new blank image with black background
            padded_image = Image.new("RGB", (new_width, new_height), (255, 215, 174))

            # Calculate the position to paste the original image
            paste_x = (new_width - original_image.width) // 2
            paste_y = (new_height - original_image.height) // 2

            # Paste the original image onto the padded image
            padded_image.paste(original_image, (paste_x, paste_y))

            padded_filename = os.path.splitext(filename)[0] + "_padded.jpg"
            output_path = os.path.join(output_folder, padded_filename)  # Use padded_filename here
            padded_image.save(output_path)

            print('Converted : ', image_count)

    print("Padding and saving complete.")

# Define your input and output paths, and other parameters
input_folder = r"C:\Users\suraj\Desktop\happy sad netural\without_padding\train\happy\1"
output_folder = r"C:\Users\suraj\Desktop\happy sad netural\without_padding\train\happy\1\1"
new_width = 224
new_height = 224
max_images = None  # Set the maximum number of images to process, or leave it as None to process all

# Call the function to pad and save images
pad_images_in_folder(input_folder, output_folder, new_width, new_height, max_images)
# Out:
# file number :  51
# Converted :  1
# Converted :  2
# Converted :  3
# Converted :  4
# Converted :  5
# Converted :  6
# Converted :  7
# Converted :  8
# Converted :  9
# Converted :  10
# Converted :  11
# Converted :  12
# Converted :  13
# Converted :  14
# Converted :  15
# Converted :  16
# Converted :  17
# Converted :  18
# Converted :  19
# Converted :  20
# Converted :  21
# Converted :  22
# Converted :  23
# Converted :  24
# Converted :  25
# Converted :  26
# Converted :  27
# Converted :  28
# Converted :  29
# Converted :  30
# Converted :  31
# Converted :  32
# Converted :  33
# Converted :  34
# Converted :  35
# Converted :  36
# Converted :  37
# Converted :  38
# Converted :  39
# Converted :  40
# Converted :  41
# Converted :  42
# Converted :  43
# Converted :  44
# Converted :  45
# Converted :  46
# Converted :  47
# Converted :  48
# Converted :  49
# Converted :  50
# Padding and saving complete.
